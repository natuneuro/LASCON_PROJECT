# %% [markdown]
# Try to charge a neuron in netpyne

# %%
# /home/lascon/Documents/241165/AberraEtAl2018/cells/L1_NGC-DA_bNAC219_2
import os
print(os.getcwd())
# !nrnivmodl 241165/AberraEtAl2018/cells/L1_NGC-DA_bNAC219_2/mechanisms
# Out:
# /home/lascon/Documents
# /home/lascon/Documents
# ...

# %%
from netpyne import specs
from neuron import h


# should go after importing netpyne
import matplotlib
# %matplotlib inline

#------------------------------------------------------------------------------
#
# NETWORK PARAMETERS
#
#------------------------------------------------------------------------------

netParams = specs.NetParams()  # object of class NetParams to store the network parameters


# Go to path needed
# /home/lascon/Documents/241165/AberraEtAl2018/cells/L1_NGC-DA_bNAC219_2

netParams.importCellParams(
    label='Cell_A',
    conds={'cellType': 'CELL', 'cellModel': 'ModelDB'},
    fileName='241165/AberraEtAl2018/cells/L1_NGC-DA_bNAC219_2/template.hoc',
    cellName= 'bNAC219_L1_NGCDA_e7cec642c3',
    cellArgs={},
    importSynMechs=True
)



'''
# Create a population of that imported cell
netParams.popParams["pop1"] = {
    "cellType": "CELL",
    "cellModel": "ModelDB",
    "numCells": 50,
    "xRange": [0, 200],
    "yRange": [0, 200],
    "zRange": [0, 200],
}
'''
# Out:
# NEURON: init not enough arguments
#  near line 0
#  ^
#         bNAC219_L1_NGCDA_e7cec642c3[0].init()
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 21
#      15 netParams = specs.NetParams()  # object of class NetParams to store the network parameters
#      18 # Go to path needed
#      19 # /home/lascon/Documents/241165/AberraEtAl2018/cells/L1_NGC-DA_bNAC219_2
# ---> 21 netParams.importCellParams(
#      22     label='Cell_A',
#      23     conds={'cellType': 'CELL', 'cellModel': 'ModelDB'},
#      24     fileName='241165/AberraEtAl2018/cells/L1_NGC-DA_bNAC219_2/template.hoc',
#      25     cellName= 'bNAC219_L1_NGCDA_e7cec642c3',
#      26     cellArgs={},
#      27     importSynMechs=True
#      28 )
#      32 '''
#      33 # Create a population of that imported cell
#      34 netParams.popParams["pop1"] = {
#    (...)     41 }
#      42 '''
#
# ...

# %%
netParams
