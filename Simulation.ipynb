# %% [markdown]
# # Simulate and save firing rate for a cell
#
# ## 1. Input parameters

# %%
# Load cells ID
import numpy as np
from pathlib import Path

layer_idx  = 1     # 0: L1, 1: L2/3, 2: L4, 3: L5, 4:L6
cell_clone = 4      # There are 5 clones, so put numbers 1-5
base_path = '/home/lascon/Documents/241165/AberraEtAl2018/cells/'

cell_number_pop = 10 # Cell number to create the population 

Cell = [
    'L1_NGCDA_bNAC219_',
    'L23_PC_cADpyr229_',  
    'L4_LBC_cACint209_',
    'L5_TTPC2_cADpyr232_',
    'L6_TPC_L4_cADpyr231_'
]



Layer = "_".join(Cell[layer_idx].split("_")[0:1])

cell_path =f'{base_path}{Cell[layer_idx]}{cell_clone}'

cell_Name_prefix = f'{"_".join(Cell[layer_idx].split("_")[2:3])}_{"_".join(Cell[layer_idx].split("_")[0:2])}_'


cell_label = "_".join(Cell[layer_idx].split("_")[1:2])
cell_type = "_".join(Cell[layer_idx].split("_")[2:3])


current_amps = np.loadtxt(f"{cell_path}/current_amps.dat") 
current_amps = current_amps[3]



print(cell_path)
print(Layer)
print(cell_label)
print(cell_type)
print(cell_Name_prefix)
print(current_amps)



from pathlib import Path

hoc_path = Path(cell_path)/ "template.hoc"   # cell_path puede ser str o Path

text = hoc_path.read_text(errors="ignore").splitlines()

# 1) Mostrar líneas donde aparece el string (con número de línea)
hits = [(i+1, line) for i, line in enumerate(text) if cell_Name_prefix in line]
print(f"Found {len(hits)} matches for '{cell_Name_prefix}' in {hoc_path}")
for ln, line in hits[:20]:  # muestra hasta 20
    print(f"{ln}: {line}")

# 2) Extraer el nombre del template si está en 'begintemplate ...' y empieza con el prefijo
templates = []
for line in text:
    s = line.strip()
    if s.startswith("begintemplate"):
        parts = s.split()
        if len(parts) >= 2 and parts[1].startswith(cell_Name_prefix):
            templates.append(parts[1])

print("Templates matching prefix:", templates)
cell_Name = templates[0]
print(cell_Name)


# Config the cell path to compile .mod files
# %cd "{cell_path}/mechanisms"
# !nrnivmodl
# Out:
# /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4
# L23
# PC
# cADpyr229
# cADpyr229_L23_PC_
# 0.1825334
# Found 2 matches for 'cADpyr229_L23_PC_' in /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/template.hoc
# 35: begintemplate cADpyr229_L23_PC_c292d67a2e
# 259: endtemplate cADpyr229_L23_PC_c292d67a2e
# Templates matching prefix: ['cADpyr229_L23_PC_c292d67a2e']
# cADpyr229_L23_PC_c292d67a2e
# /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms
# /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms
# Mod files: "./CaDynamics_E2.mod" "./Ca_HVA.mod" "./Ca_LVAst.mod" "./Ih.mod" "./Im.mod" "./K_Pst.mod" "./K_Tst.mod" "./Nap_Et2.mod" "./NaTa_t.mod" "./NaTs2_t.mod" "./ProbAMPANMDA_EMS.mod" "./ProbGABAAB_EMS.mod" "./SK_E2.mod" "./SKv3_1.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../Ca_LVAst.mod
#  -> NMODL ../CaDynamics_E2.mod
#  -> NMODL ../Ca_HVA.mod
# Translating Ca_LVAst.mod into /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms/x86_64/Ca_LVAst.cTranslating CaDynamics_E2.mod into /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms/x86_64/CaDynamics_E2.c
#
# Thread Safe
# Translating Ca_HVA.mod into /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms/x86_64/Ca_HVA.c
# Thread Safe
# Thread Safe
#  -> NMODL ../Ih.mod
#  -> NMODL ../Im.mod
#  -> NMODL ../K_Pst.mod
# Translating Ih.mod into /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms/x86_64/Ih.c
# Thread Safe
# Translating Im.mod into /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms/x86_64/Im.c
#  -> NMODL ../K_Tst.mod
# Thread Safe
#  -> NMODL ../Nap_Et2.mod
# Translating K_Tst.mod into /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms/x86_64/K_Tst.c
# Thread Safe
#  -> NMODL ../NaTa_t.mod
# Translating K_Pst.mod into /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms/x86_64/K_Pst.c
# Thread Safe
# Translating Nap_Et2.mod into /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms/x86_64/Nap_Et2.c
# Translating NaTa_t.mod into /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms/x86_64/NaTa_t.c
#  -> NMODL ../NaTs2_t.mod
# Thread Safe
# Thread Safe
#  -> NMODL ../ProbGABAAB_EMS.mod
#  -> NMODL ../ProbAMPANMDA_EMS.mod
# Translating NaTs2_t.mod into /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms/x86_64/NaTs2_t.c
# Translating ProbGABAAB_EMS.mod into /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms/x86_64/ProbGABAAB_EMS.c
# Thread Safe
# Translating ProbAMPANMDA_EMS.mod into /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms/x86_64/ProbAMPANMDA_EMS.c
# Notice: This mechanism cannot be used with CVODE
# Notice: A_GABAA discontinuity adjustment not available.
# Notice: B_GABAA discontinuity adjustment not available.
# Notice: A_GABAB discontinuity adjustment not available.
# Notice: B_GABAB discontinuity adjustment not available.
# Warning: dt undefined. (declared within VERBATIM?)
# Warning: value undefined. (declared within VERBATIM?)
# Thread Safe
#  -> NMODL ../SK_E2.mod
#  -> NMODL ../SKv3_1.mod
# Notice: This mechanism cannot be used with CVODE
# Notice: A_AMPA discontinuity adjustment not available.
# Notice: B_AMPA discontinuity adjustment not available.
# Notice: A_NMDA discontinuity adjustment not available.
# Notice: B_NMDA discontinuity adjustment not available.
# Warning: dt undefined. (declared within VERBATIM?)
# Warning: value undefined. (declared within VERBATIM?)
# Thread Safe
#  -> Compiling CaDynamics_E2.c
# Translating SK_E2.mod into /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms/x86_64/SK_E2.c
# Translating SKv3_1.mod into /home/lascon/Documents/241165/AberraEtAl2018/cells/L23_PC_cADpyr229_4/mechanisms/x86_64/SKv3_1.c
# Thread Safe
# Thread Safe
#  -> Compiling Ca_HVA.c
#  -> Compiling Ca_LVAst.c
#  -> Compiling Ih.c
#  -> Compiling Im.c
#  -> Compiling K_Pst.c
#  -> Compiling K_Tst.c
#  -> Compiling Nap_Et2.c
#  -> Compiling NaTa_t.c
#  -> Compiling NaTs2_t.c
#  -> Compiling ProbAMPANMDA_EMS.c
#  -> Compiling ProbGABAAB_EMS.c
#  -> Compiling SK_E2.c
#  -> Compiling SKv3_1.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special

# %% [markdown]
# ## 2. Cell and stimulus parameters

# %%
from neuron import h
from netpyne import specs, sim

h.chdir(cell_path)


#  load hoc
h.load_file('stdrun.hoc')
h.load_file('nrngui.hoc')
h.load_file('import3d.hoc')
h.load_file('morphology.hoc')
h.load_file('biophysics.hoc')
h.load_file('template.hoc')

# --------------------------------------------------------------

# Cell parameters

# --------------------------------------------------------------

def run_step_netpyne(step_amp, simLabel):
    sim.clearAll()  # important in loops

    netParams = specs.NetParams()
    simConfig = specs.SimConfig()

    # 1) Import the cell template -> it creates one rule com 'secs'
    netParams.importCellParams(
        label= cell_label, 
        conds={'cellType': cell_type},          # pop vai bater nessa cond
        fileName='template.hoc',
        cellName= cell_Name,
        cellArgs=[1],
        importSynMechs=False
    )

    # 2) Population  
    netParams.popParams['pop1'] = {
        'cellType': cell_type,
        'numCells': cell_number_pop
    }

    
    # 3) IClamp
    netParams.stimSourceParams['iclamp'] = {
        'type': 'IClamp',
        'del': 100.0,
        'dur': 600.0,
        'amp': float(step_amp)
    }

    netParams.rotateCellsRandomly = [0, 6.2832]

    # 4) Config sim (first create, then discover the correct name of the soma)
    simConfig.duration = 800.0
    simConfig.dt = 0.025
    simConfig.recordStep = 0.025
    simConfig.filename = simLabel
    simConfig.saveJson = True
    simConfig.createNEURONObj = True
    simConfig.cache_efficient = True
    simConfig.checkErrors = False
    simConfig.analysis = {}
    # simConfig.saveLFPCells = True
    # simConfig.recordLFP = [[50, 100, 50], [50, 200, 50]]
    simConfig.recordLFP = [
        [50, 50,  0],
        [20, 40,  0],
        [0,  45, 55],
    ]


    # criate the network (no stimulation yet) just to inspect 
    sim.create(netParams=netParams, simConfig=simConfig)

    cell = sim.net.cells[0]
    secs = list(cell.secs.keys())
    print("Secs:", secs)

    # take soma automatically
    soma_sec = None
    for cand in ['soma_0', 'soma', 'soma[0]']: #try some usual patterns that soma appears
        if cand in cell.secs:
            soma_sec = cand
            break
    if soma_sec is None:
        raise RuntimeError(f"Soma not foubd. Secs available: {secs}")

    # 5) Now define the stim and record using the correct soma name
    netParams.stimTargetParams['iclamp->pop1'] = {
        'source': 'iclamp',
        'conds': {'pop': 'pop1'},
        'sec': soma_sec,
        'loc': 0.5
    }

    simConfig.recordCells = ['all'] 
    simConfig.recordTraces = {
        'V_soma': {'sec': soma_sec, 'loc': 0.5, 'var': 'v'},
        'V_axon_0': {'sec':'axon_0', 'loc':0.5, 'var':'v'},
        'V_axon_1': {'sec':'axon_1', 'loc':0.5, 'var':'v'}, 
        'V_dend_0': {'sec':'dend_0', 'loc':0.5, 'var':'v'},                            
        'V_dend_1': {'sec':'dend_1', 'loc':0.5, 'var':'v'},            
        'V_dend_2': {'sec':'dend_2', 'loc':0.5, 'var':'v'},             
        'V_dend_3': {'sec':'dend_3', 'loc':0.5, 'var':'v'},
    }
    simConfig.recordStim = True
    simConfig.recordTime = True

    simConfig.analysis['plotTraces'] = {
        'include': ['pop1'], 
        'saveFig': False, 
        'overlay': True, 
        'oneFigPer': 'cell'}  # Plot recorded traces for this list of cells

    # simConfig.analysis['plotTraces'] = {'include': [0], 'saveFig': False}  # Plot recorded traces for this list of cells

    simConfig.analysis['plotConn'] = {'saveFig': False}    

    # 6) recreate from zero and run (to insure that stim+recordTraces work)
    sim.clearAll()
    sim.createSimulateAnalyze(netParams=netParams, simConfig=simConfig)

    sim.gatherData()                  			# gather spiking data and cell info from each node
    sim.saveData()                    			# save params, cell info and sim output to file (pickle,mat,txt,etc)#
    # sim.analysis.plotData() 


    #------------------------------------------------------------------------------
    # Saving
    #------------------------------------------------------------------------------
    simConfig.savePickle = False         	## Save pkl file
    simConfig.saveJson = True	           	## Save json file
    simConfig.saveDataInclude = ['simData'] ## , 'netParams', 'simConfig', ,'simData'
    simConfig.backupCfgFile = None
    simConfig.gatherOnlySimData = False
    simConfig.saveCellSecs = True
    simConfig.saveCellConns = True
        
    
# -------------------------------------------------------

# Compute firing rate

# -------------------------------------------------------


import json
import numpy as np
import os

def compute_firing_rate(step_idx, thresh=-20.0):

    base = cell_path
    fname = os.path.join(base, f'step_{step_idx:02d}_data.json')

    with open(fname) as f:
        data = json.load(f)

    t = np.array(data['simData']['t'])
    # v = np.array(list(data['simData']['V_soma'].values())[0])

    # automatically find the soma voltage trace
    Vtrace = None
    for key, val in data['simData'].items():
        if key.lower().startswith('v'):   # it takes V_soma, V, v_soma_0, etc.
            if isinstance(val, dict) and len(val) > 0:
                Vtrace = np.array(next(iter(val.values())))
                break
            elif isinstance(val, list):
                Vtrace = np.array(val)
                break

    if Vtrace is None:
        raise RuntimeError("voltage no found in the trace, verify recordTraces in simConfig.")

    v = Vtrace

    

    # stim window (same as in protocol)
    stim_mask = (t > 100) & (t < 700)
    t_stim = t[stim_mask]
    v_stim = v[stim_mask]

    # detect matches in the limiar (spikes)
    crossings = (v_stim[:-1] < thresh) & (v_stim[1:] >= thresh)
    spike_times = t_stim[1:][crossings]

    # stim duration in seconds
    stim_dur = (700 - 100) / 1000.0  # 0.6 s

    firing_rate = len(spike_times) / stim_dur  # Hz

    return firing_rate, spike_times
# Out:
# NEURON: unable to open font "*helvetica-medium-r-normal*--14*", using "fixed"
# 	1
# 	1
# 	1

# %% [markdown]
# ## 3. Run simulation per cell

# %%
run_step_netpyne(current_amps, simLabel=f'step_{0:02d}')
# Out:
# Starting to add synapses
# Added excitatory synapse 0 originating from cell 27809 of m-type L6_IPC on basal section 7(0.902000) and dep 667.000000
# Added excitatory synapse 1 originating from cell 27809 of m-type L6_IPC on basal section 7(0.887000) and dep 661.000000
# Added excitatory synapse 2 originating from cell 27809 of m-type L6_IPC on basal section 7(0.900000) and dep 673.000000
# Added inhibitory synapse 3 originating from cell 31411 of m-type L1_DAC on apical section 35(0.637000) and dep 608.000000
# Added inhibitory synapse 4 originating from cell 31411 of m-type L1_DAC on apical section 35(0.624000) and dep 499.000000
# Added inhibitory synapse 5 originating from cell 31411 of m-type L1_DAC on apical section 26(0.409000) and dep 780.000000
# Added inhibitory synapse 6 originating from cell 31411 of m-type L1_DAC on apical section 13(0.506000) and dep 986.000000
# Added inhibitory synapse 7 originating from cell 31411 of m-type L1_DAC on apical section 8(0.132000) and dep 582.000000
# Added inhibitory synapse 8 originating from cell 31411 of m-type L1_DAC on apical section 35(0.636000) and dep 561.000000
# Added inhibitory synapse 9 originating from cell 31411 of m-type L1_DAC on apical section 35(0.636000) and dep 896.000000
# Added inhibitory synapse 10 originating from cell 31411 of m-type L1_DAC on apical section 4(0.413000) and dep 366.000000
# Added inhibitory synapse 11 originating from cell 31411 of m-type L1_DAC on apical section 20(0.990000) and dep 714.000000
# Added inhibitory synapse 12 originating from cell 31411 of m-type L1_DAC on apical section 12(0.500000) and dep 1073.000000
# Added inhibitory synapse 13 originating from cell 31411 of m-type L1_DAC on apical section 58(0.887000) and dep 441.000000
# Added inhibitory synapse 14 originating from cell 31411 of m-type L1_DAC on apical section 34(0.831000) and dep 755.000000
# Added inhibitory synapse 15 originating from cell 31411 of m-type L1_DAC on apical section 32(0.741000) and dep 954.000000
# Added inhibitory synapse 16 originating from cell 31411 of m-type L1_DAC on apical section 4(0.691000) and dep 875.000000
# Added inhibitory synapse 17 originating from cell 31638 of m-type L1_DAC on apical section 30(0.855000) and dep 429.000000
# Added inhibitory synapse 18 originating from cell 31638 of m-type L1_DAC on apical section 30(0.889000) and dep 789.000000
# Added inhibitory synapse 19 originating from cell 31638 of m-type L1_DAC on apical section 30(0.928000) and dep 696.000000
# Added inhibitory synapse 20 originating from cell 31638 of m-type L1_DAC on apical section 30(0.962000) and dep 442.000000
# Added inhibitory synapse 21 originating from cell 31638 of m-type L1_DAC on apical section 32(0.023000) and dep 624.000000
# Added inhibitory synapse 22 originating from cell 31638 of m-type L1_DAC on apical section 32(0.187000) and dep 368.000000
# Added inhibitory synapse 23 originating from cell 31638 of m-type L1_DAC on basal section 12(0.859000) and dep 342.000000
# Added inhibitory synapse 24 originating from cell 31638 of m-type L1_DAC on apical section 55(0.847000) and dep 819.000000
# Added inhibitory synapse 25 originating from cell 31638 of m-type L1_DAC on apical section 32(0.924000) and dep 472.000000
# Added inhibitory synapse 26 originating from cell 31645 of m-type L1_HAC on apical section 4(0.532000) and dep 986.000000
# Added inhibitory synapse 27 originating from cell 31645 of m-type L1_HAC on apical section 4(0.467000) and dep 671.000000
# Added inhibitory synapse 28 originating from cell 31645 of m-type L1_HAC on apical section 4(0.452000) and dep 472.000000
# Added inhibitory synapse 29 originating from cell 31645 of m-type L1_HAC on apical section 4(0.453000) and dep 965.000000
# Added inhibitory synapse 30 originating from cell 31645 of m-type L1_HAC on apical section 4(0.451000) and dep 951.000000
# Added inhibitory synapse 31 originating from cell 31645 of m-type L1_HAC on apical section 4(0.454000) and dep 338.000000
# Added inhibitory synapse 32 originating from cell 31645 of m-type L1_HAC on apical section 4(0.482000) and dep 715.000000
# Added inhibitory synapse 33 originating from cell 31645 of m-type L1_HAC on apical section 30(0.531000) and dep 1067.000000
# Added inhibitory synapse 34 originating from cell 31734 of m-type L23_NGC on apical section 56(0.091000) and dep 457.000000
# Added inhibitory synapse 35 originating from cell 31734 of m-type L23_NGC on basal section 6(0.540000) and dep 853.000000
# Added inhibitory synapse 36 originating from cell 31734 of m-type L23_NGC on apical section 18(0.485000) and dep 935.000000
# Added inhibitory synapse 37 originating from cell 31734 of m-type L23_NGC on apical section 18(0.499000) and dep 354.000000
# Added inhibitory synapse 38 originating from cell 31734 of m-type L23_NGC on apical section 18(0.498000) and dep 846.000000
# Added inhibitory synapse 39 originating from cell 31734 of m-type L23_NGC on apical section 39(0.536000) and dep 565.000000
# Added inhibitory synapse 40 originating from cell 31734 of m-type L23_NGC on apical section 4(0.054000) and dep 994.000000
# Added inhibitory synapse 41 originating from cell 31734 of m-type L23_NGC on basal section 8(0.363000) and dep 756.000000
# Added inhibitory synapse 42 originating from cell 31734 of m-type L23_NGC on apical section 29(0.492000) and dep 670.000000
# Added inhibitory synapse 43 originating from cell 31734 of m-type L23_NGC on apical section 56(0.367000) and dep 649.000000
# Added inhibitory synapse 44 originating from cell 31734 of m-type L23_NGC on basal section 15(0.423000) and dep 914.000000
# Added inhibitory synapse 45 originating from cell 31734 of m-type L23_NGC on apical section 38(0.816000) and dep 743.000000
# Added inhibitory synapse 46 originating from cell 31734 of m-type L23_NGC on apical section 38(0.781000) and dep 436.000000
# Added inhibitory synapse 47 originating from cell 31734 of m-type L23_NGC on basal section 6(0.428000) and dep 674.000000
# Added inhibitory synapse 48 originating from cell 31734 of m-type L23_NGC on basal section 6(0.376000) and dep 439.000000
# Added inhibitory synapse 49 originating from cell 31734 of m-type L23_NGC on basal section 6(0.404000) and dep 1057.000000
# Added inhibitory synapse 50 originating from cell 31734 of m-type L23_NGC on apical section 55(0.301000) and dep 1047.000000
# Added inhibitory synapse 51 originating from cell 31734 of m-type L23_NGC on basal section 7(0.003000) and dep 1028.000000
# Added inhibitory synapse 52 originating from cell 31734 of m-type L23_NGC on apical section 17(0.281000) and dep 913.000000
# Added inhibitory synapse 53 originating from cell 31734 of m-type L23_NGC on apical section 18(0.273000) and dep 426.000000
# Added inhibitory synapse 54 originating from cell 31734 of m-type L23_NGC on basal section 12(0.998000) and dep 562.000000
# Added inhibitory synapse 55 originating from cell 31734 of m-type L23_NGC on apical section 17(0.877000) and dep 585.000000
# Added inhibitory synapse 56 originating from cell 31734 of m-type L23_NGC on apical section 17(0.175000) and dep 964.000000
# Added excitatory synapse 57 originating from cell 31739 of m-type L23_PC on apical section 39(0.100000) and dep 661.000000
# Added excitatory synapse 58 originating from cell 31739 of m-type L23_PC on apical section 54(0.935000) and dep 671.000000
# Added excitatory synapse 59 originating from cell 31739 of m-type L23_PC on apical section 17(0.160000) and dep 667.000000
# Added excitatory synapse 60 originating from cell 31753 of m-type L23_PC on basal section 7(0.215000) and dep 664.000000
# Added excitatory synapse 61 originating from cell 31753 of m-type L23_PC on apical section 56(0.886000) and dep 666.000000
# Added excitatory synapse 62 originating from cell 31790 of m-type L23_PC on apical section 59(0.542000) and dep 656.000000
# Added excitatory synapse 63 originating from cell 31790 of m-type L23_PC on basal section 12(0.704000) and dep 678.000000
# Added excitatory synapse 64 originating from cell 31790 of m-type L23_PC on apical section 54(0.059000) and dep 686.000000
# Added excitatory synapse 65 originating from cell 31790 of m-type L23_PC on apical section 62(0.063000) and dep 683.000000
# Added excitatory synapse 66 originating from cell 31794 of m-type L23_PC on basal section 3(0.913000) and dep 667.000000
# Added excitatory synapse 67 originating from cell 31794 of m-type L23_PC on apical section 20(0.343000) and dep 674.000000
# Added inhibitory synapse 68 originating from cell 31823 of m-type L23_MC on basal section 12(0.331000) and dep 1581.000000
# Added inhibitory synapse 69 originating from cell 31823 of m-type L23_MC on basal section 12(0.370000) and dep 794.000000
# Added inhibitory synapse 70 originating from cell 31823 of m-type L23_MC on basal section 12(0.414000) and dep 858.000000
# Added inhibitory synapse 71 originating from cell 31823 of m-type L23_MC on apical section 3(0.118000) and dep 814.000000
# Added inhibitory synapse 72 originating from cell 31823 of m-type L23_MC on apical section 4(0.083000) and dep 1275.000000
# Added inhibitory synapse 73 originating from cell 31823 of m-type L23_MC on apical section 1(0.630000) and dep 1021.000000
# Added inhibitory synapse 74 originating from cell 31823 of m-type L23_MC on apical section 61(0.574000) and dep 1344.000000
# Added inhibitory synapse 75 originating from cell 31823 of m-type L23_MC on apical section 21(0.626000) and dep 1329.000000
# Added inhibitory synapse 76 originating from cell 31823 of m-type L23_MC on apical section 21(0.718000) and dep 1704.000000
# Added inhibitory synapse 77 originating from cell 31823 of m-type L23_MC on basal section 4(0.851000) and dep 1653.000000
# Added excitatory synapse 78 originating from cell 31835 of m-type L23_PC on basal section 10(0.217000) and dep 664.000000
# Added excitatory synapse 79 originating from cell 31835 of m-type L23_PC on apical section 18(0.651000) and dep 656.000000
# Added excitatory synapse 80 originating from cell 31875 of m-type L23_PC on apical section 16(0.962000) and dep 675.000000
# Added excitatory synapse 81 originating from cell 31875 of m-type L23_PC on apical section 58(0.994000) and dep 669.000000
# Added excitatory synapse 82 originating from cell 31936 of m-type L23_PC on apical section 7(0.869000) and dep 665.000000
# Added excitatory synapse 83 originating from cell 31936 of m-type L23_PC on apical section 7(0.899000) and dep 686.000000
# Added excitatory synapse 84 originating from cell 31936 of m-type L23_PC on apical section 13(0.049000) and dep 674.000000
# Added excitatory synapse 85 originating from cell 31936 of m-type L23_PC on apical section 26(0.328000) and dep 678.000000
# Added excitatory synapse 86 originating from cell 31936 of m-type L23_PC on apical section 7(0.942000) and dep 660.000000
# Added excitatory synapse 87 originating from cell 31971 of m-type L23_PC on basal section 13(0.521000) and dep 661.000000
# Added excitatory synapse 88 originating from cell 31971 of m-type L23_PC on apical section 33(0.433000) and dep 665.000000
# Added excitatory synapse 89 originating from cell 32003 of m-type L23_PC on apical section 20(0.231000) and dep 677.000000
# Added excitatory synapse 90 originating from cell 32003 of m-type L23_PC on apical section 24(0.436000) and dep 684.000000
# Added excitatory synapse 91 originating from cell 32076 of m-type L23_PC on apical section 3(0.465000) and dep 682.000000
# Added excitatory synapse 92 originating from cell 32076 of m-type L23_PC on apical section 1(0.182000) and dep 672.000000
# Added excitatory synapse 93 originating from cell 32076 of m-type L23_PC on basal section 4(0.807000) and dep 661.000000
# Added excitatory synapse 94 originating from cell 32076 of m-type L23_PC on basal section 6(0.414000) and dep 677.000000
# Added excitatory synapse 95 originating from cell 32076 of m-type L23_PC on basal section 6(0.472000) and dep 675.000000
# Added excitatory synapse 96 originating from cell 32079 of m-type L23_PC on apical section 26(0.334000) and dep 676.000000
# Added excitatory synapse 97 originating from cell 32079 of m-type L23_PC on basal section 14(0.976000) and dep 658.000000
# Added excitatory synapse 98 originating from cell 32092 of m-type L23_PC on apical section 30(0.219000) and dep 672.000000
# Added excitatory synapse 99 originating from cell 32092 of m-type L23_PC on apical section 8(0.673000) and dep 668.000000
# Added excitatory synapse 100 originating from cell 32107 of m-type L23_PC on apical section 24(0.135000) and dep 666.000000
# Added excitatory synapse 101 originating from cell 32107 of m-type L23_PC on apical section 38(0.710000) and dep 672.000000
# Added excitatory synapse 102 originating from cell 32107 of m-type L23_PC on apical section 38(0.832000) and dep 670.000000
# Added excitatory synapse 103 originating from cell 32107 of m-type L23_PC on apical section 19(0.635000) and dep 671.000000
# Added excitatory synapse 104 originating from cell 32107 of m-type L23_PC on basal section 2(0.549000) and dep 662.000000
# Added excitatory synapse 105 originating from cell 32113 of m-type L23_PC on basal section 8(0.463000) and dep 665.000000
# Added excitatory synapse 106 originating from cell 32113 of m-type L23_PC on basal section 8(0.347000) and dep 686.000000
# Added excitatory synapse 107 originating from cell 32113 of m-type L23_PC on basal section 8(0.223000) and dep 664.000000
# Added excitatory synapse 108 originating from cell 32113 of m-type L23_PC on basal section 8(0.279000) and dep 678.000000
# Added excitatory synapse 109 originating from cell 32113 of m-type L23_PC on basal section 8(0.165000) and dep 667.000000
# Added excitatory synapse 110 originating from cell 32113 of m-type L23_PC on basal section 12(0.069000) and dep 672.000000
# Added excitatory synapse 111 originating from cell 32113 of m-type L23_PC on apical section 0(0.250000) and dep 686.000000
# Added excitatory synapse 112 originating from cell 32113 of m-type L23_PC on apical section 0(0.572000) and dep 674.000000
# Added excitatory synapse 113 originating from cell 32113 of m-type L23_PC on apical section 39(0.487000) and dep 680.000000
# Added excitatory synapse 114 originating from cell 32120 of m-type L23_PC on apical section 26(0.110000) and dep 668.000000
# Added excitatory synapse 115 originating from cell 32120 of m-type L23_PC on apical section 13(0.583000) and dep 659.000000
# Added excitatory synapse 116 originating from cell 32137 of m-type L23_PC on apical section 4(0.037000) and dep 666.000000
# Added excitatory synapse 117 originating from cell 32137 of m-type L23_PC on apical section 30(0.963000) and dep 671.000000
# Added excitatory synapse 118 originating from cell 32137 of m-type L23_PC on apical section 31(0.184000) and dep 654.000000
# Added excitatory synapse 119 originating from cell 32137 of m-type L23_PC on apical section 31(0.504000) and dep 658.000000
# Added inhibitory synapse 120 originating from cell 32151 of m-type L23_LBC on apical section 4(0.296000) and dep 1069.000000
# Added inhibitory synapse 121 originating from cell 32151 of m-type L23_LBC on basal section 14(0.580000) and dep 909.000000
# Added inhibitory synapse 122 originating from cell 32151 of m-type L23_LBC on apical section 26(0.271000) and dep 1004.000000
# Added inhibitory synapse 123 originating from cell 32151 of m-type L23_LBC on apical section 4(0.232000) and dep 786.000000
# Added inhibitory synapse 124 originating from cell 32151 of m-type L23_LBC on apical section 7(0.215000) and dep 774.000000
# Added inhibitory synapse 125 originating from cell 32151 of m-type L23_LBC on basal section 14(0.204000) and dep 771.000000
# Added inhibitory synapse 126 originating from cell 32151 of m-type L23_LBC on somatic section 0(0.000000) and dep 642.000000
# Added inhibitory synapse 127 originating from cell 32151 of m-type L23_LBC on basal section 13(0.126000) and dep 699.000000
# Added inhibitory synapse 128 originating from cell 32151 of m-type L23_LBC on basal section 13(0.096000) and dep 960.000000
# Added inhibitory synapse 129 originating from cell 32151 of m-type L23_LBC on basal section 14(0.182000) and dep 777.000000
# Added inhibitory synapse 130 originating from cell 32151 of m-type L23_LBC on basal section 14(0.151000) and dep 1080.000000
# Added inhibitory synapse 131 originating from cell 32151 of m-type L23_LBC on basal section 14(0.193000) and dep 717.000000
# Added inhibitory synapse 132 originating from cell 32151 of m-type L23_LBC on apical section 26(0.096000) and dep 1139.000000
# Added inhibitory synapse 133 originating from cell 32151 of m-type L23_LBC on apical section 58(0.495000) and dep 593.000000
# Added excitatory synapse 134 originating from cell 32169 of m-type L23_PC on basal section 15(0.826000) and dep 675.000000
# Added excitatory synapse 135 originating from cell 32169 of m-type L23_PC on basal section 15(0.733000) and dep 680.000000
# Added excitatory synapse 136 originating from cell 32169 of m-type L23_PC on basal section 15(0.773000) and dep 654.000000
# Added inhibitory synapse 137 originating from cell 32178 of m-type L23_MC on apical section 3(0.111000) and dep 937.000000
# Added inhibitory synapse 138 originating from cell 32178 of m-type L23_MC on apical section 34(0.065000) and dep 1409.000000
# Added inhibitory synapse 139 originating from cell 32178 of m-type L23_MC on basal section 15(0.788000) and dep 1124.000000
# Added inhibitory synapse 140 originating from cell 32178 of m-type L23_MC on basal section 15(0.826000) and dep 1087.000000
# Added inhibitory synapse 141 originating from cell 32178 of m-type L23_MC on apical section 29(0.222000) and dep 912.000000
# Added inhibitory synapse 142 originating from cell 32178 of m-type L23_MC on basal section 6(0.396000) and dep 1124.000000
# Added inhibitory synapse 143 originating from cell 32178 of m-type L23_MC on apical section 20(0.085000) and dep 1035.000000
# Added inhibitory synapse 144 originating from cell 32182 of m-type L23_SBC on apical section 59(0.460000) and dep 57.000000
# Added inhibitory synapse 145 originating from cell 32182 of m-type L23_SBC on basal section 8(0.864000) and dep 44.000000
# Added inhibitory synapse 146 originating from cell 32182 of m-type L23_SBC on apical section 39(0.537000) and dep 53.000000
# Added inhibitory synapse 147 originating from cell 32182 of m-type L23_SBC on apical section 39(0.424000) and dep 44.000000
# Added inhibitory synapse 148 originating from cell 32182 of m-type L23_SBC on basal section 3(0.814000) and dep 35.000000
# Added inhibitory synapse 149 originating from cell 32182 of m-type L23_SBC on apical section 39(0.296000) and dep 66.000000
# Added inhibitory synapse 150 originating from cell 32182 of m-type L23_SBC on apical section 39(0.880000) and dep 63.000000
# Added inhibitory synapse 151 originating from cell 32182 of m-type L23_SBC on apical section 58(0.285000) and dep 33.000000
# Added inhibitory synapse 152 originating from cell 32182 of m-type L23_SBC on apical section 58(0.486000) and dep 28.000000
# Added inhibitory synapse 153 originating from cell 32182 of m-type L23_SBC on apical section 20(0.274000) and dep 38.000000
# Added inhibitory synapse 154 originating from cell 32182 of m-type L23_SBC on apical section 20(0.256000) and dep 43.000000
# Added inhibitory synapse 155 originating from cell 32182 of m-type L23_SBC on apical section 20(0.226000) and dep 25.000000
# Added inhibitory synapse 156 originating from cell 32182 of m-type L23_SBC on apical section 20(0.269000) and dep 55.000000
# Added inhibitory synapse 157 originating from cell 32182 of m-type L23_SBC on apical section 57(0.688000) and dep 33.000000
# Added inhibitory synapse 158 originating from cell 32182 of m-type L23_SBC on apical section 61(0.300000) and dep 25.000000
# Added inhibitory synapse 159 originating from cell 32182 of m-type L23_SBC on apical section 62(0.245000) and dep 60.000000
# Added inhibitory synapse 160 originating from cell 32182 of m-type L23_SBC on apical section 37(0.116000) and dep 24.000000
# Added inhibitory synapse 161 originating from cell 32182 of m-type L23_SBC on basal section 1(0.743000) and dep 62.000000
# Added inhibitory synapse 162 originating from cell 32182 of m-type L23_SBC on basal section 3(0.225000) and dep 36.000000
# Added inhibitory synapse 163 originating from cell 32182 of m-type L23_SBC on basal section 6(0.346000) and dep 65.000000
# Added inhibitory synapse 164 originating from cell 32182 of m-type L23_SBC on basal section 12(0.323000) and dep 41.000000
# Added inhibitory synapse 165 originating from cell 32182 of m-type L23_SBC on apical section 57(0.326000) and dep 51.000000
# Added excitatory synapse 166 originating from cell 32232 of m-type L23_PC on basal section 13(0.929000) and dep 676.000000
# Added excitatory synapse 167 originating from cell 32232 of m-type L23_PC on apical section 26(0.804000) and dep 686.000000
# Added excitatory synapse 168 originating from cell 32261 of m-type L23_PC on apical section 62(0.151000) and dep 664.000000
# Added excitatory synapse 169 originating from cell 32261 of m-type L23_PC on apical section 62(0.154000) and dep 662.000000
# Added excitatory synapse 170 originating from cell 32261 of m-type L23_PC on apical section 37(0.271000) and dep 667.000000
# Added excitatory synapse 171 originating from cell 32261 of m-type L23_PC on apical section 20(0.833000) and dep 661.000000
# Added excitatory synapse 172 originating from cell 32290 of m-type L23_PC on basal section 12(0.266000) and dep 679.000000
# Added excitatory synapse 173 originating from cell 32290 of m-type L23_PC on apical section 19(0.034000) and dep 679.000000
# Added excitatory synapse 174 originating from cell 32290 of m-type L23_PC on basal section 2(0.765000) and dep 687.000000
# Added inhibitory synapse 175 originating from cell 32307 of m-type L23_DBC on basal section 12(0.897000) and dep 1005.000000
# Added inhibitory synapse 176 originating from cell 32307 of m-type L23_DBC on basal section 12(0.915000) and dep 427.000000
# Added inhibitory synapse 177 originating from cell 32307 of m-type L23_DBC on basal section 12(0.873000) and dep 637.000000
# Added inhibitory synapse 178 originating from cell 32307 of m-type L23_DBC on basal section 12(0.833000) and dep 608.000000
# Added inhibitory synapse 179 originating from cell 32307 of m-type L23_DBC on apical section 54(0.900000) and dep 579.000000
# Added inhibitory synapse 180 originating from cell 32307 of m-type L23_DBC on apical section 54(0.917000) and dep 546.000000
# Added inhibitory synapse 181 originating from cell 32307 of m-type L23_DBC on apical section 54(0.933000) and dep 1040.000000
# Added inhibitory synapse 182 originating from cell 32307 of m-type L23_DBC on apical section 17(0.043000) and dep 582.000000
# Added inhibitory synapse 183 originating from cell 32307 of m-type L23_DBC on basal section 3(0.229000) and dep 706.000000
# Added inhibitory synapse 184 originating from cell 32307 of m-type L23_DBC on basal section 3(0.211000) and dep 446.000000
# Added inhibitory synapse 185 originating from cell 32307 of m-type L23_DBC on basal section 3(0.219000) and dep 1051.000000
# Added inhibitory synapse 186 originating from cell 32307 of m-type L23_DBC on basal section 12(0.238000) and dep 595.000000
# Added inhibitory synapse 187 originating from cell 32307 of m-type L23_DBC on apical section 3(0.287000) and dep 581.000000
# Added inhibitory synapse 188 originating from cell 32307 of m-type L23_DBC on apical section 3(0.344000) and dep 428.000000
# Added inhibitory synapse 189 originating from cell 32307 of m-type L23_DBC on apical section 3(0.406000) and dep 766.000000
# Added inhibitory synapse 190 originating from cell 32307 of m-type L23_DBC on apical section 14(0.663000) and dep 611.000000
# Added inhibitory synapse 191 originating from cell 32307 of m-type L23_DBC on basal section 3(0.946000) and dep 485.000000
# Added inhibitory synapse 192 originating from cell 32307 of m-type L23_DBC on apical section 39(0.352000) and dep 582.000000
# Added inhibitory synapse 193 originating from cell 32307 of m-type L23_DBC on apical section 56(0.452000) and dep 321.000000
# Added inhibitory synapse 194 originating from cell 32307 of m-type L23_DBC on apical section 59(0.114000) and dep 608.000000
# Added inhibitory synapse 195 originating from cell 32307 of m-type L23_DBC on apical section 20(0.219000) and dep 1035.000000
# Added inhibitory synapse 196 originating from cell 32307 of m-type L23_DBC on apical section 20(0.188000) and dep 1075.000000
# Added inhibitory synapse 197 originating from cell 32307 of m-type L23_DBC on apical section 58(0.143000) and dep 346.000000
# Added excitatory synapse 198 originating from cell 32327 of m-type L23_PC on basal section 14(0.075000) and dep 682.000000
# Added excitatory synapse 199 originating from cell 32327 of m-type L23_PC on basal section 13(0.062000) and dep 661.000000
# Added excitatory synapse 200 originating from cell 32327 of m-type L23_PC on basal section 9(0.897000) and dep 669.000000
# Added excitatory synapse 201 originating from cell 32327 of m-type L23_PC on basal section 15(0.260000) and dep 665.000000
# Added excitatory synapse 202 originating from cell 32327 of m-type L23_PC on basal section 9(0.823000) and dep 677.000000
# Added excitatory synapse 203 originating from cell 32327 of m-type L23_PC on basal section 13(0.125000) and dep 667.000000
# Added inhibitory synapse 204 originating from cell 32332 of m-type L23_MC on basal section 12(0.338000) and dep 1716.000000
# Added inhibitory synapse 205 originating from cell 32332 of m-type L23_MC on apical section 16(0.234000) and dep 753.000000
# Added inhibitory synapse 206 originating from cell 32332 of m-type L23_MC on apical section 61(0.495000) and dep 899.000000
# Added inhibitory synapse 207 originating from cell 32332 of m-type L23_MC on apical section 61(0.458000) and dep 1358.000000
# Added inhibitory synapse 208 originating from cell 32332 of m-type L23_MC on apical section 55(0.760000) and dep 1356.000000
# Added inhibitory synapse 209 originating from cell 32332 of m-type L23_MC on apical section 56(0.058000) and dep 1117.000000
# Added inhibitory synapse 210 originating from cell 32332 of m-type L23_MC on apical section 20(0.169000) and dep 1256.000000
# Added inhibitory synapse 211 originating from cell 32332 of m-type L23_MC on apical section 20(0.713000) and dep 774.000000
# Added excitatory synapse 212 originating from cell 32385 of m-type L23_PC on apical section 28(0.341000) and dep 665.000000
# Added excitatory synapse 213 originating from cell 32385 of m-type L23_PC on apical section 28(0.949000) and dep 657.000000
# Added excitatory synapse 214 originating from cell 32398 of m-type L23_PC on apical section 1(0.124000) and dep 670.000000
# Added excitatory synapse 215 originating from cell 32398 of m-type L23_PC on apical section 1(0.493000) and dep 658.000000
# Added excitatory synapse 216 originating from cell 32421 of m-type L23_PC on apical section 3(0.501000) and dep 664.000000
# Added excitatory synapse 217 originating from cell 32421 of m-type L23_PC on apical section 20(0.584000) and dep 685.000000
# Added excitatory synapse 218 originating from cell 32421 of m-type L23_PC on apical section 20(0.608000) and dep 666.000000
# Added excitatory synapse 219 originating from cell 32421 of m-type L23_PC on apical section 20(0.641000) and dep 686.000000
# Added excitatory synapse 220 originating from cell 32421 of m-type L23_PC on apical section 4(0.245000) and dep 656.000000
# Added inhibitory synapse 221 originating from cell 32457 of m-type L23_DBC on basal section 12(0.351000) and dep 978.000000
# Added inhibitory synapse 222 originating from cell 32457 of m-type L23_DBC on apical section 38(0.574000) and dep 1102.000000
# Added inhibitory synapse 223 originating from cell 32457 of m-type L23_DBC on basal section 15(0.427000) and dep 665.000000
# Added inhibitory synapse 224 originating from cell 32457 of m-type L23_DBC on basal section 13(0.504000) and dep 995.000000
# Added inhibitory synapse 225 originating from cell 32457 of m-type L23_DBC on apical section 30(0.153000) and dep 1037.000000
# Added inhibitory synapse 226 originating from cell 32457 of m-type L23_DBC on apical section 20(0.013000) and dep 814.000000
# Added inhibitory synapse 227 originating from cell 32457 of m-type L23_DBC on apical section 20(0.009000) and dep 520.000000
# Added inhibitory synapse 228 originating from cell 32457 of m-type L23_DBC on apical section 20(0.018000) and dep 605.000000
# Added inhibitory synapse 229 originating from cell 32457 of m-type L23_DBC on apical section 20(0.182000) and dep 446.000000
# Added inhibitory synapse 230 originating from cell 32457 of m-type L23_DBC on apical section 58(0.326000) and dep 1020.000000
# Added inhibitory synapse 231 originating from cell 32457 of m-type L23_DBC on apical section 37(0.196000) and dep 879.000000
# Added inhibitory synapse 232 originating from cell 32457 of m-type L23_DBC on apical section 29(0.501000) and dep 583.000000
# Added inhibitory synapse 233 originating from cell 32457 of m-type L23_DBC on apical section 24(0.423000) and dep 984.000000
# Added inhibitory synapse 234 originating from cell 32457 of m-type L23_DBC on apical section 24(0.525000) and dep 986.000000
# Added inhibitory synapse 235 originating from cell 32457 of m-type L23_DBC on apical section 20(0.493000) and dep 1000.000000
# Added inhibitory synapse 236 originating from cell 32457 of m-type L23_DBC on apical section 26(0.672000) and dep 1017.000000
# Added excitatory synapse 237 originating from cell 32493 of m-type L23_PC on apical section 62(0.478000) and dep 680.000000
# Added excitatory synapse 238 originating from cell 32493 of m-type L23_PC on apical section 61(0.632000) and dep 672.000000
# Added excitatory synapse 239 originating from cell 32493 of m-type L23_PC on basal section 14(0.477000) and dep 658.000000
# Added excitatory synapse 240 originating from cell 32494 of m-type L23_PC on apical section 14(0.175000) and dep 665.000000
# Added excitatory synapse 241 originating from cell 32494 of m-type L23_PC on apical section 61(0.300000) and dep 659.000000
# Added excitatory synapse 242 originating from cell 32494 of m-type L23_PC on apical section 7(0.651000) and dep 679.000000
# Added excitatory synapse 243 originating from cell 32512 of m-type L23_PC on apical section 7(0.964000) and dep 668.000000
# Added excitatory synapse 244 originating from cell 32512 of m-type L23_PC on apical section 26(0.187000) and dep 683.000000
# Added excitatory synapse 245 originating from cell 32517 of m-type L23_PC on apical section 37(0.571000) and dep 676.000000
# Added excitatory synapse 246 originating from cell 32517 of m-type L23_PC on basal section 3(0.152000) and dep 664.000000
# Added excitatory synapse 247 originating from cell 32517 of m-type L23_PC on basal section 3(0.386000) and dep 660.000000
# Added excitatory synapse 248 originating from cell 32517 of m-type L23_PC on basal section 3(0.431000) and dep 666.000000
# Added excitatory synapse 249 originating from cell 32540 of m-type L23_PC on basal section 13(0.259000) and dep 655.000000
# Added excitatory synapse 250 originating from cell 32540 of m-type L23_PC on basal section 13(0.284000) and dep 680.000000
# Added excitatory synapse 251 originating from cell 32620 of m-type L23_PC on apical section 37(0.824000) and dep 684.000000
# Added excitatory synapse 252 originating from cell 32620 of m-type L23_PC on apical section 61(0.204000) and dep 679.000000
# Added excitatory synapse 253 originating from cell 32640 of m-type L23_PC on apical section 20(0.425000) and dep 669.000000
# Added excitatory synapse 254 originating from cell 32640 of m-type L23_PC on basal section 12(0.555000) and dep 677.000000
# Added excitatory synapse 255 originating from cell 32640 of m-type L23_PC on basal section 12(0.517000) and dep 667.000000
# Added excitatory synapse 256 originating from cell 32640 of m-type L23_PC on basal section 12(0.488000) and dep 679.000000
# Added excitatory synapse 257 originating from cell 32640 of m-type L23_PC on basal section 6(0.355000) and dep 685.000000
# Added inhibitory synapse 258 originating from cell 32693 of m-type L23_MC on apical section 4(0.190000) and dep 1150.000000
# Added inhibitory synapse 259 originating from cell 32693 of m-type L23_MC on apical section 61(0.780000) and dep 1593.000000
# Added inhibitory synapse 260 originating from cell 32693 of m-type L23_MC on apical section 61(0.812000) and dep 1121.000000
# Added inhibitory synapse 261 originating from cell 32693 of m-type L23_MC on apical section 7(0.015000) and dep 1165.000000
# Added inhibitory synapse 262 originating from cell 32693 of m-type L23_MC on apical section 25(0.526000) and dep 1138.000000
# Added inhibitory synapse 263 originating from cell 32693 of m-type L23_MC on apical section 29(0.806000) and dep 809.000000
# Added inhibitory synapse 264 originating from cell 32693 of m-type L23_MC on apical section 29(0.869000) and dep 795.000000
# Added inhibitory synapse 265 originating from cell 32693 of m-type L23_MC on apical section 7(0.579000) and dep 1501.000000
# Added inhibitory synapse 266 originating from cell 32693 of m-type L23_MC on apical section 26(0.680000) and dep 1522.000000
# Added excitatory synapse 267 originating from cell 32801 of m-type L23_PC on apical section 20(0.896000) and dep 679.000000
# Added excitatory synapse 268 originating from cell 32801 of m-type L23_PC on apical section 29(0.331000) and dep 667.000000
# Added excitatory synapse 269 originating from cell 32801 of m-type L23_PC on apical section 38(0.682000) and dep 672.000000
# Added excitatory synapse 270 originating from cell 32801 of m-type L23_PC on basal section 3(0.558000) and dep 657.000000
# Added excitatory synapse 271 originating from cell 32801 of m-type L23_PC on basal section 6(0.661000) and dep 657.000000
# Added excitatory synapse 272 originating from cell 32812 of m-type L23_PC on apical section 1(0.722000) and dep 685.000000
# Added excitatory synapse 273 originating from cell 32812 of m-type L23_PC on apical section 59(0.060000) and dep 679.000000
# Added excitatory synapse 274 originating from cell 32833 of m-type L23_PC on apical section 16(0.553000) and dep 664.000000
# Added excitatory synapse 275 originating from cell 32833 of m-type L23_PC on apical section 59(0.334000) and dep 658.000000
# Added excitatory synapse 276 originating from cell 32833 of m-type L23_PC on apical section 30(0.218000) and dep 681.000000
# Added excitatory synapse 277 originating from cell 32836 of m-type L23_PC on apical section 55(0.787000) and dep 686.000000
# Added excitatory synapse 278 originating from cell 32836 of m-type L23_PC on apical section 55(0.803000) and dep 658.000000
# Added excitatory synapse 279 originating from cell 32836 of m-type L23_PC on apical section 55(0.802000) and dep 670.000000
# Added excitatory synapse 280 originating from cell 32842 of m-type L23_PC on basal section 6(0.427000) and dep 672.000000
# Added excitatory synapse 281 originating from cell 32842 of m-type L23_PC on apical section 19(0.743000) and dep 687.000000
# Added excitatory synapse 282 originating from cell 32842 of m-type L23_PC on apical section 24(0.394000) and dep 672.000000
# Added excitatory synapse 283 originating from cell 32842 of m-type L23_PC on apical section 24(0.489000) and dep 669.000000
# Added excitatory synapse 284 originating from cell 32842 of m-type L23_PC on basal section 8(0.797000) and dep 667.000000
# Added excitatory synapse 285 originating from cell 32842 of m-type L23_PC on apical section 37(0.873000) and dep 656.000000
# Added excitatory synapse 286 originating from cell 32851 of m-type L23_PC on apical section 41(0.715000) and dep 658.000000
# Added excitatory synapse 287 originating from cell 32851 of m-type L23_PC on basal section 8(0.541000) and dep 681.000000
# Added excitatory synapse 288 originating from cell 32899 of m-type L23_PC on basal section 15(0.597000) and dep 686.000000
# Added excitatory synapse 289 originating from cell 32899 of m-type L23_PC on basal section 8(0.343000) and dep 673.000000
# Added excitatory synapse 290 originating from cell 32910 of m-type L23_PC on apical section 34(0.125000) and dep 655.000000
# Added excitatory synapse 291 originating from cell 32910 of m-type L23_PC on apical section 58(0.508000) and dep 656.000000
# Added excitatory synapse 292 originating from cell 32959 of m-type L23_PC on apical section 4(0.010000) and dep 680.000000
# Added excitatory synapse 293 originating from cell 32959 of m-type L23_PC on apical section 3(0.963000) and dep 681.000000
# Added excitatory synapse 294 originating from cell 32959 of m-type L23_PC on apical section 3(0.014000) and dep 671.000000
# Added excitatory synapse 295 originating from cell 32959 of m-type L23_PC on apical section 14(0.243000) and dep 670.000000
# Added excitatory synapse 296 originating from cell 32959 of m-type L23_PC on apical section 3(0.973000) and dep 666.000000
# Added excitatory synapse 297 originating from cell 32959 of m-type L23_PC on apical section 4(0.019000) and dep 681.000000
# Added excitatory synapse 298 originating from cell 32964 of m-type L23_PC on apical section 61(0.135000) and dep 676.000000
# Added excitatory synapse 299 originating from cell 32964 of m-type L23_PC on apical section 61(0.205000) and dep 674.000000
# Added excitatory synapse 300 originating from cell 32995 of m-type L23_PC on basal section 12(0.252000) and dep 664.000000
# Added excitatory synapse 301 originating from cell 32995 of m-type L23_PC on basal section 12(0.468000) and dep 668.000000
# Added excitatory synapse 302 originating from cell 32995 of m-type L23_PC on apical section 38(0.360000) and dep 683.000000
# Added excitatory synapse 303 originating from cell 32995 of m-type L23_PC on apical section 38(0.472000) and dep 668.000000
# Added excitatory synapse 304 originating from cell 32995 of m-type L23_PC on apical section 16(0.408000) and dep 673.000000
# Added excitatory synapse 305 originating from cell 32995 of m-type L23_PC on apical section 54(0.515000) and dep 665.000000
# Added excitatory synapse 306 originating from cell 33033 of m-type L23_PC on basal section 15(0.033000) and dep 688.000000
# Added excitatory synapse 307 originating from cell 33033 of m-type L23_PC on basal section 15(0.042000) and dep 686.000000
# Added excitatory synapse 308 originating from cell 33033 of m-type L23_PC on apical section 3(0.248000) and dep 676.000000
# Added excitatory synapse 309 originating from cell 33033 of m-type L23_PC on apical section 58(0.300000) and dep 661.000000
# Added excitatory synapse 310 originating from cell 33045 of m-type L23_PC on apical section 37(0.175000) and dep 659.000000
# Added excitatory synapse 311 originating from cell 33045 of m-type L23_PC on basal section 2(0.309000) and dep 670.000000
# Added excitatory synapse 312 originating from cell 33045 of m-type L23_PC on apical section 41(0.578000) and dep 671.000000
# Added excitatory synapse 313 originating from cell 33068 of m-type L23_PC on basal section 13(0.879000) and dep 676.000000
# Added excitatory synapse 314 originating from cell 33068 of m-type L23_PC on apical section 35(0.208000) and dep 657.000000
# Added excitatory synapse 315 originating from cell 33068 of m-type L23_PC on apical section 37(0.092000) and dep 686.000000
# Added excitatory synapse 316 originating from cell 33068 of m-type L23_PC on apical section 38(0.326000) and dep 655.000000
# Added excitatory synapse 317 originating from cell 33086 of m-type L23_PC on basal section 14(0.015000) and dep 668.000000
# Added excitatory synapse 318 originating from cell 33086 of m-type L23_PC on basal section 15(0.044000) and dep 675.000000
# Added excitatory synapse 319 originating from cell 33086 of m-type L23_PC on apical section 26(0.616000) and dep 668.000000
# Added excitatory synapse 320 originating from cell 33093 of m-type L23_PC on apical section 13(0.644000) and dep 675.000000
# Added excitatory synapse 321 originating from cell 33093 of m-type L23_PC on apical section 4(0.164000) and dep 684.000000
# Added excitatory synapse 322 originating from cell 33093 of m-type L23_PC on apical section 8(0.958000) and dep 656.000000
# Added excitatory synapse 323 originating from cell 33093 of m-type L23_PC on apical section 26(0.461000) and dep 667.000000
# Added inhibitory synapse 324 originating from cell 33115 of m-type L23_NBC on basal section 14(0.696000) and dep 771.000000
# Added inhibitory synapse 325 originating from cell 33115 of m-type L23_NBC on basal section 14(0.666000) and dep 807.000000
# Added inhibitory synapse 326 originating from cell 33115 of m-type L23_NBC on apical section 4(0.549000) and dep 823.000000
# Added inhibitory synapse 327 originating from cell 33115 of m-type L23_NBC on apical section 4(0.551000) and dep 593.000000
# Added inhibitory synapse 328 originating from cell 33115 of m-type L23_NBC on apical section 4(0.551000) and dep 922.000000
# Added inhibitory synapse 329 originating from cell 33115 of m-type L23_NBC on apical section 4(0.128000) and dep 762.000000
# Added inhibitory synapse 330 originating from cell 33115 of m-type L23_NBC on apical section 4(0.117000) and dep 764.000000
# Added inhibitory synapse 331 originating from cell 33115 of m-type L23_NBC on apical section 4(0.113000) and dep 915.000000
# Added inhibitory synapse 332 originating from cell 33115 of m-type L23_NBC on apical section 26(0.158000) and dep 1001.000000
# Added inhibitory synapse 333 originating from cell 33115 of m-type L23_NBC on apical section 4(0.111000) and dep 1016.000000
# Added inhibitory synapse 334 originating from cell 33115 of m-type L23_NBC on apical section 26(0.102000) and dep 775.000000
# Added excitatory synapse 335 originating from cell 33127 of m-type L23_PC on apical section 4(0.051000) and dep 667.000000
# Added excitatory synapse 336 originating from cell 33127 of m-type L23_PC on apical section 28(0.336000) and dep 682.000000
# Added excitatory synapse 337 originating from cell 33160 of m-type L23_PC on basal section 13(0.462000) and dep 664.000000
# Added excitatory synapse 338 originating from cell 33160 of m-type L23_PC on apical section 8(0.013000) and dep 669.000000
# Added excitatory synapse 339 originating from cell 33193 of m-type L23_PC on apical section 41(0.680000) and dep 662.000000
# Added excitatory synapse 340 originating from cell 33193 of m-type L23_PC on apical section 41(0.690000) and dep 687.000000
# Added excitatory synapse 341 originating from cell 33204 of m-type L23_PC on basal section 13(0.075000) and dep 664.000000
# Added excitatory synapse 342 originating from cell 33204 of m-type L23_PC on basal section 13(0.202000) and dep 662.000000
# Added excitatory synapse 343 originating from cell 33219 of m-type L23_PC on basal section 9(0.426000) and dep 678.000000
# Added excitatory synapse 344 originating from cell 33219 of m-type L23_PC on apical section 0(0.478000) and dep 670.000000
# Added excitatory synapse 345 originating from cell 33219 of m-type L23_PC on apical section 37(0.198000) and dep 679.000000
# Added excitatory synapse 346 originating from cell 33219 of m-type L23_PC on basal section 2(0.865000) and dep 670.000000
# Added excitatory synapse 347 originating from cell 33250 of m-type L23_PC on apical section 0(0.500000) and dep 672.000000
# Added excitatory synapse 348 originating from cell 33250 of m-type L23_PC on apical section 29(0.356000) and dep 682.000000
# Added excitatory synapse 349 originating from cell 33250 of m-type L23_PC on apical section 30(0.357000) and dep 662.000000
# Added excitatory synapse 350 originating from cell 33250 of m-type L23_PC on apical section 33(0.913000) and dep 673.000000
# Added excitatory synapse 351 originating from cell 33250 of m-type L23_PC on apical section 8(0.519000) and dep 676.000000
# Added excitatory synapse 352 originating from cell 33377 of m-type L23_PC on apical section 37(0.575000) and dep 670.000000
# Added excitatory synapse 353 originating from cell 33377 of m-type L23_PC on basal section 3(0.091000) and dep 664.000000
# Added excitatory synapse 354 originating from cell 33377 of m-type L23_PC on apical section 3(0.054000) and dep 680.000000
# Added excitatory synapse 355 originating from cell 33439 of m-type L23_PC on basal section 14(0.194000) and dep 672.000000
# Added excitatory synapse 356 originating from cell 33439 of m-type L23_PC on apical section 3(0.764000) and dep 674.000000
# Added excitatory synapse 357 originating from cell 33439 of m-type L23_PC on apical section 12(0.219000) and dep 670.000000
# Added excitatory synapse 358 originating from cell 33475 of m-type L23_PC on apical section 28(0.825000) and dep 670.000000
# Added excitatory synapse 359 originating from cell 33475 of m-type L23_PC on apical section 34(0.290000) and dep 668.000000
# Added excitatory synapse 360 originating from cell 33475 of m-type L23_PC on apical section 35(0.324000) and dep 661.000000
# Added inhibitory synapse 361 originating from cell 33498 of m-type L23_NBC on apical section 61(0.433000) and dep 925.000000
# Added inhibitory synapse 362 originating from cell 33498 of m-type L23_NBC on apical section 61(0.450000) and dep 997.000000
# Added inhibitory synapse 363 originating from cell 33498 of m-type L23_NBC on apical section 61(0.472000) and dep 1128.000000
# Added inhibitory synapse 364 originating from cell 33498 of m-type L23_NBC on apical section 61(0.475000) and dep 963.000000
# Added inhibitory synapse 365 originating from cell 33498 of m-type L23_NBC on apical section 28(0.167000) and dep 629.000000
# Added inhibitory synapse 366 originating from cell 33498 of m-type L23_NBC on apical section 28(0.212000) and dep 894.000000
# Added inhibitory synapse 367 originating from cell 33498 of m-type L23_NBC on apical section 29(0.588000) and dep 1024.000000
# Added inhibitory synapse 368 originating from cell 33498 of m-type L23_NBC on apical section 58(0.893000) and dep 707.000000
# Added inhibitory synapse 369 originating from cell 33498 of m-type L23_NBC on apical section 58(0.943000) and dep 674.000000
# Added inhibitory synapse 370 originating from cell 33498 of m-type L23_NBC on apical section 61(0.432000) and dep 704.000000
# Added inhibitory synapse 371 originating from cell 33498 of m-type L23_NBC on apical section 61(0.333000) and dep 907.000000
# Added inhibitory synapse 372 originating from cell 33498 of m-type L23_NBC on apical section 37(0.779000) and dep 866.000000
# Added inhibitory synapse 373 originating from cell 33498 of m-type L23_NBC on apical section 16(0.979000) and dep 955.000000
# Added inhibitory synapse 374 originating from cell 33498 of m-type L23_NBC on apical section 38(0.747000) and dep 633.000000
# Added inhibitory synapse 375 originating from cell 33498 of m-type L23_NBC on basal section 3(0.231000) and dep 1023.000000
# Added inhibitory synapse 376 originating from cell 33498 of m-type L23_NBC on basal section 15(0.700000) and dep 948.000000
# Added inhibitory synapse 377 originating from cell 33498 of m-type L23_NBC on apical section 37(0.618000) and dep 1118.000000
# Added inhibitory synapse 378 originating from cell 33498 of m-type L23_NBC on apical section 55(0.874000) and dep 1002.000000
# Added inhibitory synapse 379 originating from cell 33498 of m-type L23_NBC on apical section 61(0.121000) and dep 1054.000000
# Added inhibitory synapse 380 originating from cell 33498 of m-type L23_NBC on apical section 41(0.066000) and dep 685.000000
# Added inhibitory synapse 381 originating from cell 33498 of m-type L23_NBC on apical section 41(0.071000) and dep 708.000000
# Added inhibitory synapse 382 originating from cell 33498 of m-type L23_NBC on apical section 46(0.766000) and dep 823.000000
# Added inhibitory synapse 383 originating from cell 33498 of m-type L23_NBC on apical section 41(0.077000) and dep 965.000000
# Added excitatory synapse 384 originating from cell 33619 of m-type L23_PC on basal section 15(0.388000) and dep 656.000000
# Added excitatory synapse 385 originating from cell 33619 of m-type L23_PC on basal section 15(0.388000) and dep 668.000000
# Added excitatory synapse 386 originating from cell 33619 of m-type L23_PC on basal section 15(0.387000) and dep 668.000000
# Added excitatory synapse 387 originating from cell 33619 of m-type L23_PC on apical section 26(0.028000) and dep 670.000000
# ...
# Added inhibitory synapse 1000 originating from cell 47699 of m-type L5_MC on apical section 59(0.011000) and dep 1129.000000
# Added inhibitory synapse 1001 originating from cell 47699 of m-type L5_MC on apical section 56(0.144000) and dep 1437.000000
# Added inhibitory synapse 1002 originating from cell 47699 of m-type L5_MC on apical section 58(0.119000) and dep 1564.000000
# Added inhibitory synapse 1003 originating from cell 47699 of m-type L5_MC on apical section 56(0.141000) and dep 813.000000
# Added inhibitory synapse 1004 originating from cell 47699 of m-type L5_MC on apical section 59(0.067000) and dep 1065.000000
# Added inhibitory synapse 1005 originating from cell 47699 of m-type L5_MC on apical section 55(0.941000) and dep 1300.000000
# Added inhibitory synapse 1006 originating from cell 47699 of m-type L5_MC on apical section 16(0.256000) and dep 1752.000000
# Added inhibitory synapse 1007 originating from cell 47699 of m-type L5_MC on basal section 7(0.752000) and dep 1312.000000
# Added inhibitory synapse 1008 originating from cell 47699 of m-type L5_MC on apical section 39(0.411000) and dep 1504.000000
# Added excitatory synapse 1009 originating from cell 47780 of m-type L5_TTPC1 on basal section 12(0.377000) and dep 685.000000
# Added excitatory synapse 1010 originating from cell 47780 of m-type L5_TTPC1 on apical section 38(0.481000) and dep 672.000000
# Added excitatory synapse 1011 originating from cell 49012 of m-type L5_TTPC1 on basal section 2(0.183000) and dep 666.000000
# Added excitatory synapse 1012 originating from cell 49012 of m-type L5_TTPC1 on basal section 3(0.170000) and dep 672.000000
# Added excitatory synapse 1013 originating from cell 49144 of m-type L5_UTPC on basal section 13(0.585000) and dep 672.000000
# Added excitatory synapse 1014 originating from cell 49144 of m-type L5_UTPC on basal section 8(0.191000) and dep 662.000000
# Added inhibitory synapse 1015 originating from cell 49883 of m-type L5_MC on apical section 26(0.546000) and dep 961.000000
# Added inhibitory synapse 1016 originating from cell 49883 of m-type L5_MC on apical section 26(0.461000) and dep 1629.000000
# Added inhibitory synapse 1017 originating from cell 49883 of m-type L5_MC on apical section 8(0.589000) and dep 1346.000000
# Added inhibitory synapse 1018 originating from cell 49883 of m-type L5_MC on basal section 14(1.000000) and dep 1094.000000
# Added inhibitory synapse 1019 originating from cell 49883 of m-type L5_MC on apical section 8(0.553000) and dep 1332.000000
# Added inhibitory synapse 1020 originating from cell 49883 of m-type L5_MC on apical section 28(0.456000) and dep 1761.000000
# Added inhibitory synapse 1021 originating from cell 49883 of m-type L5_MC on apical section 20(0.263000) and dep 1289.000000
# Added inhibitory synapse 1022 originating from cell 49883 of m-type L5_MC on apical section 37(0.387000) and dep 753.000000
# Added inhibitory synapse 1023 originating from cell 49883 of m-type L5_MC on apical section 28(0.764000) and dep 1347.000000
# Added excitatory synapse 1024 originating from cell 51116 of m-type L6_UTPC on apical section 20(0.466000) and dep 661.000000
# Added excitatory synapse 1025 originating from cell 51116 of m-type L6_UTPC on apical section 17(0.735000) and dep 664.000000
# Added excitatory synapse 1026 originating from cell 52572 of m-type L6_BPC on basal section 10(0.146000) and dep 662.000000
# Added excitatory synapse 1027 originating from cell 52572 of m-type L6_BPC on basal section 15(0.420000) and dep 662.000000
# Added excitatory synapse 1028 originating from cell 55174 of m-type L6_UTPC on basal section 2(0.765000) and dep 683.000000
# Added excitatory synapse 1029 originating from cell 55174 of m-type L6_UTPC on basal section 2(0.583000) and dep 662.000000
# Added excitatory synapse 1030 originating from cell 59842 of m-type L6_TPC_L4 on basal section 8(0.737000) and dep 665.000000
# Added excitatory synapse 1031 originating from cell 59842 of m-type L6_TPC_L4 on basal section 8(0.739000) and dep 679.000000
# Added excitatory synapse 1032 originating from cell 59842 of m-type L6_TPC_L4 on basal section 8(0.737000) and dep 684.000000
# Added excitatory synapse 1033 originating from cell 60784 of m-type L6_BPC on apical section 20(0.403000) and dep 657.000000
# Added excitatory synapse 1034 originating from cell 60784 of m-type L6_BPC on apical section 37(0.355000) and dep 673.000000
# Added inhibitory synapse 1035 originating from cell 62733 of m-type L1_DAC on apical section 9(0.626000) and dep 676.000000
# Added inhibitory synapse 1036 originating from cell 62733 of m-type L1_DAC on apical section 35(0.016000) and dep 816.000000
# Added inhibitory synapse 1037 originating from cell 62733 of m-type L1_DAC on apical section 4(0.320000) and dep 427.000000
# Added inhibitory synapse 1038 originating from cell 62733 of m-type L1_DAC on apical section 8(0.818000) and dep 498.000000
# Added inhibitory synapse 1039 originating from cell 62733 of m-type L1_DAC on apical section 4(0.327000) and dep 508.000000
# Added inhibitory synapse 1040 originating from cell 62733 of m-type L1_DAC on apical section 4(0.392000) and dep 845.000000
# Added inhibitory synapse 1041 originating from cell 62733 of m-type L1_DAC on apical section 4(0.605000) and dep 1099.000000
# Added inhibitory synapse 1042 originating from cell 62733 of m-type L1_DAC on apical section 4(0.619000) and dep 930.000000
# Added inhibitory synapse 1043 originating from cell 62733 of m-type L1_DAC on apical section 4(0.633000) and dep 872.000000
# Added excitatory synapse 1044 originating from cell 67685 of m-type L23_PC on apical section 37(0.494000) and dep 685.000000
# Added excitatory synapse 1045 originating from cell 67685 of m-type L23_PC on apical section 37(0.541000) and dep 658.000000
# Added excitatory synapse 1046 originating from cell 67685 of m-type L23_PC on apical section 62(0.219000) and dep 678.000000
# Added excitatory synapse 1047 originating from cell 69557 of m-type L23_PC on apical section 13(0.237000) and dep 674.000000
# Added excitatory synapse 1048 originating from cell 69557 of m-type L23_PC on apical section 13(0.167000) and dep 663.000000
# Added excitatory synapse 1049 originating from cell 69944 of m-type L23_PC on basal section 14(0.247000) and dep 663.000000
# Added excitatory synapse 1050 originating from cell 69944 of m-type L23_PC on apical section 25(0.402000) and dep 681.000000
# Added excitatory synapse 1051 originating from cell 76194 of m-type L5_TTPC1 on basal section 0(0.242000) and dep 663.000000
# Added excitatory synapse 1052 originating from cell 76194 of m-type L5_TTPC1 on apical section 58(0.746000) and dep 682.000000
# Added excitatory synapse 1053 originating from cell 92191 of m-type L6_TPC_L1 on apical section 3(0.972000) and dep 676.000000
# Added excitatory synapse 1054 originating from cell 92191 of m-type L6_TPC_L1 on apical section 4(0.010000) and dep 678.000000
# Added excitatory synapse 1055 originating from cell 119724 of m-type L6_IPC on basal section 12(0.634000) and dep 681.000000
# Added excitatory synapse 1056 originating from cell 119724 of m-type L6_IPC on apical section 19(0.638000) and dep 675.000000
# Added excitatory synapse 1057 originating from cell 126354 of m-type L23_PC on apical section 13(0.911000) and dep 679.000000
# Added excitatory synapse 1058 originating from cell 126354 of m-type L23_PC on basal section 2(0.401000) and dep 669.000000
# Added excitatory synapse 1059 originating from cell 127336 of m-type L23_PC on apical section 20(0.499000) and dep 671.000000
# Added excitatory synapse 1060 originating from cell 127336 of m-type L23_PC on apical section 1(0.924000) and dep 676.000000
# Added excitatory synapse 1061 originating from cell 127336 of m-type L23_PC on apical section 1(0.744000) and dep 664.000000
# Added excitatory synapse 1062 originating from cell 127336 of m-type L23_PC on apical section 1(0.837000) and dep 676.000000
# Added excitatory synapse 1063 originating from cell 127336 of m-type L23_PC on apical section 14(0.585000) and dep 657.000000
# Added excitatory synapse 1064 originating from cell 127829 of m-type L23_PC on basal section 2(0.351000) and dep 662.000000
# Added excitatory synapse 1065 originating from cell 127829 of m-type L23_PC on apical section 9(0.083000) and dep 679.000000
# Added excitatory synapse 1066 originating from cell 127951 of m-type L23_PC on apical section 30(0.757000) and dep 666.000000
# Added excitatory synapse 1067 originating from cell 127951 of m-type L23_PC on basal section 13(0.601000) and dep 674.000000
# Added inhibitory synapse 1068 originating from cell 128069 of m-type L23_NBC on apical section 8(0.609000) and dep 693.000000
# Added inhibitory synapse 1069 originating from cell 128069 of m-type L23_NBC on apical section 8(0.615000) and dep 939.000000
# Added inhibitory synapse 1070 originating from cell 128069 of m-type L23_NBC on apical section 8(0.612000) and dep 789.000000
# Added inhibitory synapse 1071 originating from cell 128069 of m-type L23_NBC on apical section 8(0.376000) and dep 598.000000
# Added inhibitory synapse 1072 originating from cell 128069 of m-type L23_NBC on apical section 24(0.228000) and dep 1097.000000
# Added inhibitory synapse 1073 originating from cell 128069 of m-type L23_NBC on apical section 8(0.757000) and dep 652.000000
# Added inhibitory synapse 1074 originating from cell 128069 of m-type L23_NBC on apical section 8(0.750000) and dep 920.000000
# Added inhibitory synapse 1075 originating from cell 128069 of m-type L23_NBC on apical section 34(0.981000) and dep 855.000000
# Added inhibitory synapse 1076 originating from cell 128069 of m-type L23_NBC on apical section 34(0.976000) and dep 854.000000
# Added inhibitory synapse 1077 originating from cell 128069 of m-type L23_NBC on apical section 9(0.103000) and dep 838.000000
# Added inhibitory synapse 1078 originating from cell 128069 of m-type L23_NBC on apical section 9(0.558000) and dep 1001.000000
# Added inhibitory synapse 1079 originating from cell 128069 of m-type L23_NBC on apical section 34(0.977000) and dep 1059.000000
# Added inhibitory synapse 1080 originating from cell 128069 of m-type L23_NBC on apical section 34(0.304000) and dep 631.000000
# Added excitatory synapse 1081 originating from cell 128637 of m-type L23_PC on apical section 0(0.347000) and dep 673.000000
# Added excitatory synapse 1082 originating from cell 128637 of m-type L23_PC on apical section 0(0.827000) and dep 655.000000
# Added excitatory synapse 1083 originating from cell 128637 of m-type L23_PC on apical section 38(0.510000) and dep 661.000000
# Added excitatory synapse 1084 originating from cell 128637 of m-type L23_PC on apical section 15(0.695000) and dep 659.000000
# Added excitatory synapse 1085 originating from cell 128789 of m-type L23_PC on apical section 4(0.244000) and dep 679.000000
# Added excitatory synapse 1086 originating from cell 128789 of m-type L23_PC on apical section 8(0.187000) and dep 669.000000
# Added inhibitory synapse 1087 originating from cell 128871 of m-type L23_MC on apical section 8(0.737000) and dep 810.000000
# Added inhibitory synapse 1088 originating from cell 128871 of m-type L23_MC on apical section 30(0.623000) and dep 1122.000000
# Added inhibitory synapse 1089 originating from cell 128871 of m-type L23_MC on apical section 9(0.810000) and dep 1574.000000
# Added inhibitory synapse 1090 originating from cell 128871 of m-type L23_MC on apical section 9(0.809000) and dep 1404.000000
# Added inhibitory synapse 1091 originating from cell 128871 of m-type L23_MC on apical section 9(0.809000) and dep 1729.000000
# Added inhibitory synapse 1092 originating from cell 128871 of m-type L23_MC on apical section 58(0.390000) and dep 1472.000000
# Added inhibitory synapse 1093 originating from cell 128871 of m-type L23_MC on apical section 9(0.818000) and dep 1127.000000
# Added inhibitory synapse 1094 originating from cell 128871 of m-type L23_MC on apical section 9(0.970000) and dep 937.000000
# Added inhibitory synapse 1095 originating from cell 128871 of m-type L23_MC on apical section 9(0.805000) and dep 1511.000000
# Added excitatory synapse 1096 originating from cell 130192 of m-type L23_PC on apical section 1(0.857000) and dep 679.000000
# Added excitatory synapse 1097 originating from cell 130192 of m-type L23_PC on basal section 2(0.195000) and dep 663.000000
# Added excitatory synapse 1098 originating from cell 130192 of m-type L23_PC on basal section 2(0.244000) and dep 668.000000
# Added inhibitory synapse 1099 originating from cell 132291 of m-type L23_MC on apical section 4(0.450000) and dep 1466.000000
# Added inhibitory synapse 1100 originating from cell 132291 of m-type L23_MC on apical section 12(0.206000) and dep 1105.000000
# Added inhibitory synapse 1101 originating from cell 132291 of m-type L23_MC on apical section 34(0.827000) and dep 1519.000000
# Added inhibitory synapse 1102 originating from cell 132291 of m-type L23_MC on apical section 34(0.774000) and dep 1738.000000
# Added inhibitory synapse 1103 originating from cell 132291 of m-type L23_MC on apical section 30(0.994000) and dep 1441.000000
# Added inhibitory synapse 1104 originating from cell 132291 of m-type L23_MC on apical section 12(0.389000) and dep 816.000000
# Added inhibitory synapse 1105 originating from cell 132291 of m-type L23_MC on apical section 9(0.079000) and dep 994.000000
# Added inhibitory synapse 1106 originating from cell 132291 of m-type L23_MC on apical section 12(0.062000) and dep 1440.000000
# Added excitatory synapse 1107 originating from cell 134028 of m-type L4_PC on basal section 2(0.059000) and dep 669.000000
# Added excitatory synapse 1108 originating from cell 134028 of m-type L4_PC on apical section 16(0.881000) and dep 687.000000
# Added excitatory synapse 1109 originating from cell 147507 of m-type L6_TPC_L1 on basal section 15(0.896000) and dep 654.000000
# Added excitatory synapse 1110 originating from cell 147507 of m-type L6_TPC_L1 on apical section 9(0.314000) and dep 674.000000
# Added excitatory synapse 1111 originating from cell 172828 of m-type L5_TTPC2 on apical section 4(0.101000) and dep 680.000000
# Added excitatory synapse 1112 originating from cell 172828 of m-type L5_TTPC2 on apical section 26(0.140000) and dep 657.000000
#
# Start time:  2026-01-28 17:55:46.026818
# Creating network of 1 cell populations on 1 hosts...: 100%|##########|
#   Number of cells on node 0: 10
#   Done; cell creation time = 0.67 s.
# Making connections...
#   Number of connections on node 0: 0
#   Done; cell connection time = 0.00 s.
#   Number of stims on node 0: 0
#   Done; cell stims creation time = 0.00 s.
# Secs: ['soma_0', 'dend_0', 'dend_1', 'dend_2', 'dend_3', 'dend_4', 'dend_5', 'dend_6', 'dend_7', 'dend_8', 'dend_9', 'dend_10', 'dend_11', 'dend_12', 'dend_13', 'dend_14', 'dend_15', 'apic_0', 'apic_1', 'apic_2', 'apic_3', 'apic_4', 'apic_5', 'apic_6', 'apic_7', 'apic_8', 'apic_9', 'apic_10', 'apic_11', 'apic_12', 'apic_13', 'apic_14', 'apic_15', 'apic_16', 'apic_17', 'apic_18', 'apic_19', 'apic_20', 'apic_21', 'apic_22', 'apic_23', 'apic_24', 'apic_25', 'apic_26', 'apic_27', 'apic_28', 'apic_29', 'apic_30', 'apic_31', 'apic_32', 'apic_33', 'apic_34', 'apic_35', 'apic_36', 'apic_37', 'apic_38', 'apic_39', 'apic_40', 'apic_41', 'apic_42', 'apic_43', 'apic_44', 'apic_45', 'apic_46', 'apic_47', 'apic_48', 'apic_49', 'apic_50', 'apic_51', 'apic_52', 'apic_53', 'apic_54', 'apic_55', 'apic_56', 'apic_57', 'apic_58', 'apic_59', 'apic_60', 'apic_61', 'apic_62', 'axon_0', 'axon_1']
#
# Start time:  2026-01-28 17:55:47.025626
# Creating network of 1 cell populations on 1 hosts...: 100%|##########|
#   Number of cells on node 0: 10
#   Done; cell creation time = 0.60 s.
# Making connections...
#   Number of connections on node 0: 0
#   Done; cell connection time = 0.00 s.
# Adding stims...
#   Number of stims on node 0: 10
#   Done; cell stims creation time = 0.02 s.
# Recording 70 traces of 7 types on node 0
#
# Running simulation using NEURON for 800.0 ms...
